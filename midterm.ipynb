# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Verdadero o falso con argumentos
# Pamela Pupiales 213871

# %% [markdown]
# ### 1.  Una función recursiva resuelve un problema resolviendo una parte mas pequeña del mismo problema

# %% [markdown]
# Verdadero, ya que el problema se resuelve tratando de resolverlo a una escala mas pequeña, llamando la función sucesivamente hasta llegar al caso base.

# %% [markdown]
# ### 2.  Los modelos computacionales nos ayudan a analizar la complejidad de los algoritmos, ya que nos proveen de las especificaciones de la computadora en la cual estos se ejecutarían idealmente

# %% [markdown]
# Verdadero, ya que estos modelos nos muestran las operaciones/acciones que realizan los algoritmos, a través de el costo de cada una de las operaciones se puede determinar un costo total. Esto es importante, esencialmente para tiempos de ejecución, memoria.

# %% [markdown]
# ### 3.  La búsqueda en un árbol binario de búsqueda es siempre mas rápida que la búsqueda lineal en un arreglo

# %% [markdown]
# No siempre, ya que las búsquedas en un árbol binario tienen complejidad de O(log n) en cuanto a la búsqueda en un arreglo lineal en el peor de los casos tiene complejidad O(n), en el mejor de los casos para el arreglo lineal la complejidad es O(1) lo cual es mejor que O(log n)

# %% [markdown]
# ### 4. Un algoritmo de complejidad O(nlog(n)) es mas rápido que un algoritmo de complejidad O(n)

# %% [markdown]
# Falso, ya que la complejidad de O(n) es mejor debido a que es lineal en cambio O(nlog(n)) es casi lineal, por lo que tambien indica que sus complejidades tienen una diferencia minima, al realizar una tabla de valores se puede ver que:
# x= 1, 2, 3, ........., 1000
# Para O(n)
# f(x)= 1, 2, 3, ......, 1000
# Para O(nlog(n))
# F(x)= 0, 0.60, 1.43, 3000

# %% [markdown]
# ### 5.  Un algoritmo de complejidad Ω(nlog(n)) es mas rápido que un algoritmo de complejidad Ω(n)

# %% [markdown]
# Falso, ya que es Big Ω n no resulta ser mayor a nlog(n), no se cumple, el razonamiento es casi igual a O(nlog(n)) con O(n) a pesar de ser O limite superior y Ω limite inferior ambos siguen la misma logica de complejidad.

# %% [markdown]
# ## Problemas de programación
# #### Todo el código debe ser en Python. Si se requiere escribir funciones que hagan búsqueda o ordenamiento (search, sort), programe las funciones usando los conceptos aprendidos en clase. No use las funciones que Python provee para hacer esto.

# %% [markdown]
# ### 6. Dada una lista enlazada que represente un número. Por ejemplo, 123 es representado por la lista 1->2->3 si la lista es simple o con doble enlace si es doble. Escriba un programa que haga lo siguiente:
#
# 1. Reciba dos números A y B como input
#
# 2. Transforme estos números a listas enlazadas como la definida arriba
#
# 3. Implemente la resta de los números descritos por esas listas enlazadas. El resultado (A-B) debe ser almacenado en una lista enlazada.
#
# 4. Imprima el resultado concatenando el valor de los nodos de la lista enlazada resultante
#
# Nota: asuma que el número A es mayor que B

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next_= None
        
class Singly_linked_list:
    def __init__(self):
        self.head_node = None
        self.nodos = 0
        
#Insertar al final
    def insertfin(self,val):
        nuevoN= Node(val)
        if (not self.head_node):
            self.head_node = nuevoN
        else:
            a= self.head_node
            
            while(a.next_):
                a = a.next_
            a.next_ = nuevoN
        self.nodos = self.nodos+1
    
#Longitud 
    def longitud(self):
        return self.nodos 
    
    def resta(self, l1, l2):
        llev=0
        A = None
        B = None
        
        while l1!= None and l2!=None:
            
            res_ = 0
            res1_ = 0
            res2_ = 0
            
            if l1!=None:
                res1_+= l1.val
            if l2!=None:
                res2_+= l2.val
            
            if (llev):
                res1_-= 1
                llev = False
   
            if (res1_ < res2_):
                llev = True
                res1_ += 10
 
            res_= res1_-res2_
                
            A = Node(res_)
 
            if self.head_node is None:
                self.head_node = A
            else:
                B.next_ = A
 
            B = A
        
            if l1 is not None:
                l1 = l1.next_
            if l2 is not None:
                l2 = l2.next_
 
        if llev > 0:
            A.next_ = Node(llev)
 
    def listprint(self):
        printval = self.head_node
        print("Lista["+str(self.nodos)+"]", end= "->")
        
        while printval != None:
            print (printval.val, end =" => ")
            printval = printval.next_
        print("None")
        
        
lista = Singly_linked_list()
lista2 = Singly_linked_list()
listaR = Singly_linked_list()

data1 = input("Ingrese con espacios: ")
numbers1 = map(int, data1.split())

for i in numbers1:
    lista.insertfin(i)
    
data2 = input("Ingrese con espacios: ")
numbers2 = map(int, data2.split())

for j in numbers2:
    lista2.insertfin(j)
    
listaR.resta(lista.head_node, lista2.head_node)

lista.listprint()
lista2.listprint()
listaR.listprint()
# Out:
# Ingrese con espacios: 1 3 6
# Ingrese con espacios: 1 2 2
# Lista[3]->1 => 3 => 6 => None
# Lista[3]->1 => 2 => 2 => None
# Lista[0]->0 => 1 => 4 => None

# %% [markdown]
# ### 7.  Cuando introducimos el concepto de pilas (stacks), usamos como ejemplos una pila de platos. Siguiendo con el ejemplo, una pila de platos con muchos platos se puede caer. Para evitar esto, se puede empezar una nueva pila.
#
# Implemente una clase de Python que defina un arreglo de stacks. La idea de tener este arreglo es que cuando un stack alcance su capacidad máxima, un nuevo stack empieza en el mismo arreglo. Las operación pop() debe retornar el mismo valor que lo haría si estuviéramos usando un stack simple.
#
# Nota: Debe definir los elementos de la clase: el arreglo de stacks, la capacidad del arreglo (# de stacks en el arreglo), la capacidad de cada stack (# de elementos que puede tener el stack).
#
# Hint: Cuando ingrese elementos (push), los elementos van al stack que este activo (el stack que recibe y retira elementos). Debe manejar las condiciones para cambiar el stack activo (cuando un push() deja al stack sin elementos, o cuando un pop() llena el stack).

# %%
import ctypes
class Stack(object):

    def __init__(self, val=None, val2=None):
        self.active = 0
        self.val = val
        self.val2 = val2
        self.stack = self._create_stack(self.val, self.val2)   
        self.array = self._create_array(self.val2)
    
    def _create_array(self,val2): 
        return (val2 * ctypes.py_object)()
    
    def _create_stack(self, val, val2):
        return (val * ctypes.py_object)()
    
    def push(self, item):
        if self.active == self.val2:
            if self.active == self.val:
                raise ValueError("no mas capacidad")
        self.stack[self.active] = item
        self.active += 1
        print("siguiente stack")
        
        self.array[self.active].push(self.stack)
        self.active += 1
        print("siguiente posicion array")
        
            
    def pop(self):
                 
        c = self.stack[self.active-1]
        self.stack[self.active] = ctypes.py_object
        self.active -= 1
        return c
    
    def listprint(self):
        printval = self.val
        printval2 = self.val2
        
        print("Lista["+str(self.active)+"]", end= "->")
        
        while printval2 != None:
            while printval != None:
                print (printval, end =" => ")
                printval = printval.active
            print("None")
            print (printval, end =" => ")
            printval = printval2.active
        print("None")
        
    
cre = Stack(val=4, val2=6)
cre.push(3)
cre.push(5)
cre.push(9)
cre.push(1)
cre.push2()
cre.listprint()
# Out:
# siguiente stack
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-dd1be0b87306> in <module>
#      52
#      53 cre = Stack(val=4, val2=6)
# ---> 54 cre.push(3)
#      55 cre.push(5)
#      56 cre.push(9)
#
# <ipython-input-133-dd1be0b87306> in push(self, item)
#      23         print("siguiente stack")
#      24
# ---> 25         self.array[self.active].push(self.stack)
#      26         self.active += 1
#      27         print("siguiente posicion array")
#
# ValueError: PyObject is NULL

# %%
class Array(object):
    def __init__(self, n):
        self.item_count = 0
        self.arrayS = [Stacks(n)]*n
    def push (self, item):
        for i in self.n:
            if sefl.arrayS[-i].item_count == self.n:
                raise ValueError("no mas capacidad")
            if (self.arrayS[i].item_count != self.arrayS[i].n):
                self.arrayS[i].push(item)
                if (self.arrayS[i].item_count == 0):
                    self.item_count +=1
                break
            else:
                self.arrayS[i+1].push(itemn)
                self.arrayS[i+1].item_count +=1
                self.item_count +=1
    def pop(self):
        c= self.arrayS[self.item_count -1].pop()
        if self.arrayS[self.item_count -1].item_count ==0:
            self.item_count -=1
        return c

A= Array
A.push(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-f5d8805973bd> in <module>
#      23
#      24 A= Array
# ---> 25 A.push(2)
#
# TypeError: push() missing 1 required positional argument: 'item'

# %% [markdown]
# ### 8. Dada una cola con prioridad (PriorityQueue) que contiene elementos (k,v) donde k define la prioridad y v define el valor. Recuerde que los valores con menor k tienen mayor prioridad, es decir si tenemos dos elementos (k1, v1) y (k2, v2), v2 tiene preferencia para salir de la cola antes que v1 si k2< k1. Definimos algunas de las operaciones como siguen:
#
# ```
# import ctypes
#
# class PriorityQueue(object):
#
# """
#
# Implementation of the queue data structure
#
# """
#
# def __init__(self, n):
#
# self.item_count = 0
#
# self.n = n
#
# self.queue = self._create_queue(self.n)
#
# def _create_queue(self, n):
#
# """
#
# Creates a new stack of capacity n
#
# """
#
# return (n * ctypes.py_object)()
#
# def dequeue(self):
#
# """
#
# Remove an element from the queue
#
# """
#
# c = self.queue[0]
#
# for i in range(1,self.item_count):
#
# self.queue[i-1] = self.queue[i]
#
# self.queue[self.item_count - 1] = ctypes.py_object
#
# self.item_count -= 1
#
# return c
# ```
#
# ### Implemente los métodos enqueue y decreaseKey, tal que ambos métodos tengan complejidad O(log(n)), sin utilizar funciones nativas de Python. Por ejemplo, si necesita hacer una búsqueda, no use la función de Python que implementa esto, programe la función usando for o while loops.

# %%
import ctypes

class PriorityQueue: 
    
    def __init__(self, n): 
        self.item_count = 0 
        self.n = n 
        self.queue = self._create_queue(self.n)
        
    def _create_queue(self, n):
        return (n * ctypes.py_object)()
    
    def binarySearch(self, item, low, high):
        while (low <= high):
            mid = low + (high - low) // 2
            if (item == self.queue[mid]):
                return mid + 1
            elif (item > self.queue[mid]):
                low = mid + 1
            else:
                high = mid - 1
        return low
    
    def enqueue(self, L, n):
        self.queue = L
        for i in range (n):
            j = i - 1
            selected = self.queue[i] 
            loc = self.binarySearch(selected, 0, j)
        
            while (j >= loc):
                self.queue[j + 1] = self.queue[j]
                j-=1
            self.queue[j + 1] = selected       
        
    def dequeue(self):
        c = self.queue[0]
        
        for i in range(1,self.item_count):
            self.queue[i-1] = self.queue[i]
            self.queue[self.item_count - 1] = ctypes.py_object
            self.item_count -= 1
        
        print(c,"Valor eliminado")
        
    def decreaseKey(self,v,k):
        ind = 0
        while ind < len(self.queue):
            if self.queue[ind][1] == v:
                break
            else:
                ind += 1
        if ind == len(self.queue):
            raise ValueError("Value not found")
        self.queue[ind][0] = k
        
    def traverse(self):
        for i in self.queue:
            print(i)


a = [5,8,1,4] 
n= len(a)
Qu = PriorityQueue(n) 
Qu.enqueue(a, n)
Qu.traverse()
Qu.dequeue()
Qu.dequeue()
Qu.decreaseKey(1,3)
# Out:
# 1
# 4
# 5
# 8
# 1 Valor eliminado
# 1 Valor eliminado
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-5abaee07de84> in <module>
#      67 Qu.dequeue()
#      68 Qu.dequeue()
# ---> 69 Qu.decreaseKey(1,3)
#
# <ipython-input-131-5abaee07de84> in decreaseKey(self, v, k)
#      47         ind = 0
#      48         while ind < len(self.queue):
# ---> 49             if self.queue[ind][1] == v:
#      50                 break
#      51             else:
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ### 9. Tenemos un árbol binario (binary tree), definimos a un nodo X como rojo, si todos los nodos en el recorrido de la raiz al nodo X tienen un valor que es menor o igual a X. Por ejemplo, en el ejemplo de abajo:
#
# ![](./binary_tree.png)
#
# El recorrido hacia el nodo 3 de la izquierda es 3 → 1 → 3, como todos los valores en este recorrido son menores o iguales a 3 (3=3 y 1<3), el nodo es rojo. Similarmente, en el sub-árbol de la derecha, los nodos 4 y 5 también son rojos. Escriba una función en Python que cuente el numero total de nodos rojos. El input de esta función es la raíz del árbol binario.

# %%
class TreeNode:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

    def preorderTraversalrec(self, root):
        if root is None:
            return []

        out = [root.val]
        out += self.preorderTraversalrec(root.left)
        out += self.preorderTraversalrec(root.right)

        return out

    def NodeRed(self, root):

        if root is None:
            return []
        M = [root.val]
        N = [root.val]

        M += self.NodeRed(root.left)
        N += self.NodeRed(root.right)
        
            
    def NodeM(M):
        for i in M:
            M1 = []
            if i<1:
                if i is max(M):
                    M1 += [i]
                
            if i>0:
                M.pop(0)
                if i is max(M):
                    M1 += [i]
                
            print("Longitud", len(M1))
            
    def NodeN(N):
        for i in N:
            N1 = []
            if i<1:
                if i is min(N):
                    N1 += [i]
                
            if i>0:
                N.pop(0)
                if i is max(N):
                    N1 += [i]
                
            print("Longitud", len(N1))

        
        

c = TreeNode(3)
b = TreeNode(1, left=c)

g = TreeNode(5)
f = TreeNode(1)
e = TreeNode(4, left=f, right=g)

a = TreeNode(3, left=b, right=e)

A = TreeNode

a.preorderTraversalrec(a)
a.NodeRed(a)
A.NodeM(self.M)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-fe5d90190767> in <module>
#      70
#      71 a.preorderTraversalrec(a)
# ---> 72 a.NodeRed(a)
#      73 A.NodeM(self.M)
#
# <ipython-input-76-fe5d90190767> in NodeRed(self, root)
#      22         N = [root.val]
#      23
# ---> 24         M += self.NodeRed(root.left)
#      25         N += self.NodeRed(root.right)
#      26
#
# <ipython-input-76-fe5d90190767> in NodeRed(self, root)
#      22         N = [root.val]
#      23
# ---> 24         M += self.NodeRed(root.left)
#      25         N += self.NodeRed(root.right)
#      26
#
# TypeError: 'NoneType' object is not iterable
